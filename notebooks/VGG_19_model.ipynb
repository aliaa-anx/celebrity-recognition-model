# %% [markdown]
# <a href="https://colab.research.google.com/github/aliaa-anx/celebrity-recognition-model/blob/aliaa/VGG_19_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import os

# %%
import zipfile
import os
zip_path = "/content/drive/MyDrive/VGGFace2_balanced_900_albumentations.zip"
extract_path = "/content/dataset"     # folder where files will be extracted
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset unzipped successfully!")
# List the first few items
print(os.listdir(extract_path))
# Out:
# Dataset unzipped successfully!
# ['VGGFace2_balanced_900_albumentations']

# %%
import random
dataset_path = "/content/dataset/VGGFace2_balanced_900_albumentations"

valid_ext = (".jpg", ".jpeg", ".png")
all_image_paths = [
    os.path.join(dp, f)
    for dp, dn, files in os.walk(dataset_path)
    for f in files if f.lower().endswith(valid_ext)
]
random.shuffle(all_image_paths)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import numpy as np
import os

dataset_path = "/content/dataset/VGGFace2_balanced_900_albumentations"
class_names = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])

IMAGE_SIZE = (224, 224)
target_per_class = 1500

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.9, 1.1]
)

for class_name in class_names:
    class_folder = os.path.join(dataset_path, class_name)
    images = [f for f in os.listdir(class_folder) if f.endswith(('.jpg','.png'))]
    num_existing = len(images)
    idx = 0
    while num_existing < target_per_class:
        img_path = os.path.join(class_folder, images[idx % len(images)])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, IMAGE_SIZE)
        img = np.expand_dims(img, 0)

        for batch in datagen.flow(img, batch_size=1):
            aug_img = batch[0].astype(np.uint8)
            save_path = os.path.join(class_folder, f"aug_{num_existing}.jpg")
            cv2.imwrite(save_path, cv2.cvtColor(aug_img, cv2.COLOR_RGB2BGR))
            num_existing += 1
            break
        idx += 1

print("Dataset expanded to 1500 images per class!")
# Out:
# Dataset expanded to 1500 images per class!

# %% [markdown]
# normalization

# %%
import os
import random
import tensorflow as tf

IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
NUM_CLASSES = 15
# 3. Create dataset paths and shuffle

random.seed(42)
random.shuffle(all_image_paths)

print(f"Total images found: {len(all_image_paths)}")

# 3. SPLIT DATA (70% Train, 15% Val, 15% Test)
total_images = len(all_image_paths)
train_size = int(0.7 * total_images)
val_size = int(0.15 * total_images)

train_paths = all_image_paths[:train_size]
val_paths = all_image_paths[train_size:train_size + val_size]
test_paths = all_image_paths[train_size + val_size:]

print(f"Training: {len(train_paths)}, Validation: {len(val_paths)}, Test: {len(test_paths)}")
# Out:
# Total images found: 13500
# Training: 9450, Validation: 2025, Test: 2025

# %%
# Map class names to integers
dataset_path = os.path.join(extract_path, "VGGFace2_balanced_900_albumentations")
class_names = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
class_to_int = {c:i for i,c in enumerate(sorted(os.listdir(dataset_path)))}


def process_path(file_path):
    # extract class folder name
    class_name = tf.strings.split(file_path, "/")[-2]

    # Python function to convert class name → label
    def get_label(x):
        x = x.numpy().decode("utf-8")   # convert Tensor → Python string
        return class_to_int[x]

    label = tf.py_function(get_label, [class_name], Tout=tf.int32)
    label.set_shape([])

    # load image
    img = tf.io.read_file(file_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)

    return img, label

def configure_for_performance(ds):
    ds = ds.cache()
    ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

train_ds = configure_for_performance(tf.data.Dataset.from_tensor_slices(train_paths).map(process_path, num_parallel_calls=tf.data.AUTOTUNE))
val_ds = configure_for_performance(tf.data.Dataset.from_tensor_slices(val_paths).map(process_path, num_parallel_calls=tf.data.AUTOTUNE))
test_ds = configure_for_performance(tf.data.Dataset.from_tensor_slices(test_paths).map(process_path, num_parallel_calls=tf.data.AUTOTUNE))

print("Datasets ready ")
# Out:
# Datasets ready

# %%
def build_vgg19_model(input_shape, num_classes):
    model = models.Sequential(name="VGG-19")




    model.add(layers.Input(shape=input_shape))


    # Block 1  contains 2 convultional layers and 1 max pooling layer
    # activation relu>> to add complexity and non-linearity to the model
    #padding same>> to maintain the spatial dimensions of the input (will be halved after max pooling)

    # first and 2nd blocks have 64 filters each and rest of the blocks as we go
    # deeper will have 128,256,512,512 filters respectively  to notioce more complex features as we go deeper


    model.add(layers.Conv2D(64,(3,3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2), strides=(2,2)))

    # Block 2 contains 2 convultional layers and 1 max pooling layer
    model.add(layers.Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2), strides=(2,2)))

    # Block 3 contains 4 convultional layers and 1 max pooling layer
    model.add(layers.Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2), strides=(2,2)))

    # Block 4 contains 4 convultional layers and 1 max pooling layer
    model.add(layers.Conv2D(512,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu',   padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2), strides=(2,2)))

    # Block 5 contains 4 convultional layers and 1 max pooling layer
    model.add(layers.Conv2D(512,(3,3), activation='relu',   padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu', padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu',   padding='same'))
    model.add(layers.Conv2D(512,(3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2), strides=(2,2)))


    # Flattening the layers to feed into fully connected layers(Dense layers considered the brain of the model)
    #model.add(layers.Flatten())

    #we have 3 dense layers in VGG-19
    #OPTION1 (HIGH RAM usage)
    # dense layer-1 with 4096 neurons and relu activation function
    #model.add(layers.Dense(4096, activation='relu'))
    #model.add(layers.Dropout(0.5)) #dropout to prevent overfitting


    # dense layer-2 with 4096 neurons and relu activation function
    #model.add(layers.Dense(4096, activation='relu'))
    #model.add(layers.Dropout(0.5))

    #less ram usage by 50%

    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))




    return model

print("VGG-19 architecture defined. ")
# Out:
# VGG-19 architecture defined.

# %%
# full_dataset is your ImageFolder before splitting
num_classes = 15

input_shape = (224, 224, 3)  # for VGG-19

model = build_vgg19_model(input_shape, num_classes)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "VGG-19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         7,695 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,294,735 (77.42 MB)
#  Trainable params: 20,294,735 (77.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

# Adam optimizer
optimizer = Adam(learning_rate=1e-4)

# Compile the Keras model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',  #keras map file names to integers
    metrics=['accuracy']
)

print("Optimization setup done. Using Adam optimizer for Keras model.")
# Out:
# Optimization setup done. Using Adam optimizer for Keras model.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Save the best model based on validation accuracy
checkpoint_cb = ModelCheckpoint(
    "/content/drive/MyDrive/best_vgg19_model.keras",   # file to save the model
    monitor="val_accuracy",  # metric to monitor
    save_best_only=True,     # save only the best version
    mode="max",
    verbose=1
)

# Optional: stop training early if no improvement
earlystop_cb = EarlyStopping(
    monitor="val_accuracy",
    patience=5,             # stop if no improvement for 5 epochs
    restore_best_weights=True,
    verbose=1
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,               # to test
    callbacks=[checkpoint_cb, earlystop_cb]
)
# Out:
# Epoch 1/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.0683 - loss: 2.7109
# Epoch 1: val_accuracy improved from -inf to 0.05975, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 286s 820ms/step - accuracy: 0.0683 - loss: 2.7109 - val_accuracy: 0.0598 - val_loss: 2.7081
# Epoch 2/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.0730 - loss: 2.7083
# Epoch 2: val_accuracy improved from 0.05975 to 0.06963, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 192s 650ms/step - accuracy: 0.0730 - loss: 2.7083 - val_accuracy: 0.0696 - val_loss: 2.7082
# Epoch 3/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.0650 - loss: 2.7080
# Epoch 3: val_accuracy did not improve from 0.06963
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 187s 633ms/step - accuracy: 0.0651 - loss: 2.7080 - val_accuracy: 0.0696 - val_loss: 2.7083
# Epoch 4/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.0678 - loss: 2.7083
# Epoch 4: val_accuracy improved from 0.06963 to 0.07210, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 197s 666ms/step - accuracy: 0.0678 - loss: 2.7083 - val_accuracy: 0.0721 - val_loss: 2.7072
# Epoch 5/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.0940 - loss: 2.6104
# Epoch 5: val_accuracy improved from 0.07210 to 0.13284, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 199s 672ms/step - accuracy: 0.0941 - loss: 2.6100 - val_accuracy: 0.1328 - val_loss: 2.2686
# Epoch 6/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.1331 - loss: 2.3128
# Epoch 6: val_accuracy improved from 0.13284 to 0.17185, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 197s 665ms/step - accuracy: 0.1331 - loss: 2.3128 - val_accuracy: 0.1719 - val_loss: 2.2042
# Epoch 7/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.1697 - loss: 2.2263
# Epoch 7: val_accuracy improved from 0.17185 to 0.26469, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 203s 684ms/step - accuracy: 0.1698 - loss: 2.2261 - val_accuracy: 0.2647 - val_loss: 2.0524
# Epoch 8/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.2516 - loss: 2.0598
# Epoch 8: val_accuracy improved from 0.26469 to 0.33086, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 203s 686ms/step - accuracy: 0.2517 - loss: 2.0596 - val_accuracy: 0.3309 - val_loss: 1.8748
# Epoch 9/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.3087 - loss: 1.9070
# Epoch 9: val_accuracy improved from 0.33086 to 0.39654, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 197s 664ms/step - accuracy: 0.3087 - loss: 1.9068 - val_accuracy: 0.3965 - val_loss: 1.7158
# Epoch 10/10
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.3714 - loss: 1.7503
# Epoch 10: val_accuracy improved from 0.39654 to 0.49778, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 201s 681ms/step - accuracy: 0.3715 - loss: 1.7501 - val_accuracy: 0.4978 - val_loss: 1.5244
# Restoring model weights from the end of the best epoch: 10.

# %%
from tensorflow.keras.models import load_model

model = load_model("/content/drive/MyDrive/best_vgg19_model.keras")

from tensorflow.keras.optimizers import Adam

learning_rate = 1e-4
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss="sparse_categorical_crossentropy",  # assuming integer labels
    metrics=["accuracy"]
)
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[checkpoint_cb, earlystop_cb],
)
# Out:
# Epoch 1/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.4838 - loss: 1.4605
# Epoch 1: val_accuracy improved from 0.49778 to 0.58074, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 210s 676ms/step - accuracy: 0.4839 - loss: 1.4603 - val_accuracy: 0.5807 - val_loss: 1.2721
# Epoch 2/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.5762 - loss: 1.2301
# Epoch 2: val_accuracy improved from 0.58074 to 0.66222, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 201s 680ms/step - accuracy: 0.5762 - loss: 1.2299 - val_accuracy: 0.6622 - val_loss: 1.0453
# Epoch 3/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.6388 - loss: 1.0592
# Epoch 3: val_accuracy did not improve from 0.66222
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 189s 639ms/step - accuracy: 0.6389 - loss: 1.0590 - val_accuracy: 0.6425 - val_loss: 1.0698
# Epoch 4/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.6858 - loss: 0.9265
# Epoch 4: val_accuracy improved from 0.66222 to 0.68840, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 203s 687ms/step - accuracy: 0.6859 - loss: 0.9262 - val_accuracy: 0.6884 - val_loss: 0.9353
# Epoch 5/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.7341 - loss: 0.7901
# Epoch 5: val_accuracy improved from 0.68840 to 0.76494, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 205s 693ms/step - accuracy: 0.7342 - loss: 0.7899 - val_accuracy: 0.7649 - val_loss: 0.7622
# Epoch 6/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.7860 - loss: 0.6466
# Epoch 6: val_accuracy did not improve from 0.76494
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 189s 640ms/step - accuracy: 0.7861 - loss: 0.6465 - val_accuracy: 0.7427 - val_loss: 0.8206
# Epoch 7/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.8101 - loss: 0.5704
# Epoch 7: val_accuracy improved from 0.76494 to 0.78519, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 207s 700ms/step - accuracy: 0.8101 - loss: 0.5703 - val_accuracy: 0.7852 - val_loss: 0.7856
# Epoch 8/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.8405 - loss: 0.4681
# Epoch 8: val_accuracy did not improve from 0.78519
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 641ms/step - accuracy: 0.8405 - loss: 0.4680 - val_accuracy: 0.7743 - val_loss: 0.7242
# Epoch 9/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.8645 - loss: 0.4168
# Epoch 9: val_accuracy improved from 0.78519 to 0.81086, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 205s 693ms/step - accuracy: 0.8645 - loss: 0.4168 - val_accuracy: 0.8109 - val_loss: 0.6349
# Epoch 10/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.8794 - loss: 0.3665
# Epoch 10: val_accuracy improved from 0.81086 to 0.82568, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 206s 695ms/step - accuracy: 0.8794 - loss: 0.3664 - val_accuracy: 0.8257 - val_loss: 0.6385
# Epoch 11/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9092 - loss: 0.2948
# Epoch 11: val_accuracy did not improve from 0.82568
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 641ms/step - accuracy: 0.9093 - loss: 0.2948 - val_accuracy: 0.8227 - val_loss: 0.6113
# Epoch 12/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.8993 - loss: 0.3077
# Epoch 12: val_accuracy did not improve from 0.82568
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 189s 639ms/step - accuracy: 0.8994 - loss: 0.3075 - val_accuracy: 0.8198 - val_loss: 0.7278
# Epoch 13/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9307 - loss: 0.2151
# Epoch 13: val_accuracy improved from 0.82568 to 0.83556, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 210s 709ms/step - accuracy: 0.9307 - loss: 0.2151 - val_accuracy: 0.8356 - val_loss: 0.5607
# Epoch 14/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9400 - loss: 0.1749
# Epoch 14: val_accuracy did not improve from 0.83556
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 641ms/step - accuracy: 0.9400 - loss: 0.1748 - val_accuracy: 0.8301 - val_loss: 0.6151
# Epoch 15/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9339 - loss: 0.2049
# Epoch 15: val_accuracy improved from 0.83556 to 0.85037, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 205s 695ms/step - accuracy: 0.9339 - loss: 0.2049 - val_accuracy: 0.8504 - val_loss: 0.5676
# Epoch 16/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9475 - loss: 0.1558
# Epoch 16: val_accuracy improved from 0.85037 to 0.85926, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 211s 713ms/step - accuracy: 0.9475 - loss: 0.1557 - val_accuracy: 0.8593 - val_loss: 0.5505
# Epoch 17/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9492 - loss: 0.1604
# Epoch 17: val_accuracy did not improve from 0.85926
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 642ms/step - accuracy: 0.9492 - loss: 0.1604 - val_accuracy: 0.8479 - val_loss: 0.6088
# Epoch 18/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9632 - loss: 0.1140
# Epoch 18: val_accuracy improved from 0.85926 to 0.88148, saving model to /content/drive/MyDrive/best_vgg19_model.keras
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 216s 729ms/step - accuracy: 0.9632 - loss: 0.1141 - val_accuracy: 0.8815 - val_loss: 0.5041
# Epoch 19/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9543 - loss: 0.1409
# Epoch 19: val_accuracy did not improve from 0.88148
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 641ms/step - accuracy: 0.9543 - loss: 0.1409 - val_accuracy: 0.8598 - val_loss: 0.5918
# Epoch 20/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9686 - loss: 0.1058
# Epoch 20: val_accuracy did not improve from 0.88148
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 642ms/step - accuracy: 0.9686 - loss: 0.1057 - val_accuracy: 0.8681 - val_loss: 0.6567
# Epoch 21/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9661 - loss: 0.1097
# Epoch 21: val_accuracy did not improve from 0.88148
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 642ms/step - accuracy: 0.9661 - loss: 0.1096 - val_accuracy: 0.8632 - val_loss: 0.5468
# Epoch 22/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9614 - loss: 0.1092
# Epoch 22: val_accuracy did not improve from 0.88148
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 642ms/step - accuracy: 0.9614 - loss: 0.1092 - val_accuracy: 0.8795 - val_loss: 0.5605
# Epoch 23/100
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9805 - loss: 0.0669
# Epoch 23: val_accuracy did not improve from 0.88148
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 190s 641ms/step - accuracy: 0.9805 - loss: 0.0670 - val_accuracy: 0.8770 - val_loss: 0.5278
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %% [markdown]
# **evaluation**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
import tensorflow as tf

# %%
# Evaluate on the test dataset to get the "Real World" accuracy
test_loss, test_acc = model.evaluate(test_ds)
print(f"Final Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 217ms/step - accuracy: 0.8788 - loss: 0.4926
# Final Test Accuracy: 87.26%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# 1. Get Predictions on Test Data
print("Generating predictions... (This might take a moment)")
y_true = []
y_pred = []

# Iterate over the test dataset to get actual vs predicted values
for images, labels in test_ds:
    preds = model.predict(images, verbose=0)
    # Convert probabilities to class index (0, 1, 2...)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

# 2. Create the Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# 3. Plotting
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix: Who is getting confused with whom?')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# 4. Print a Text Report (Precision/Recall per person)
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Generating predictions... (This might take a moment)
#                           precision    recall  f1-score   support
#
#         Aditi Rao Hydari       0.81      0.91      0.86       149
# Adrienne Bailon-Houghton       0.88      0.81      0.84       158
#     Alberto Núñez Feijóo       0.94      0.80      0.86       128
#   Aleksander Kwaśniewski       0.94      0.89      0.91       146
#   Aleksandra Kwaśniewska       0.89      0.76      0.82       140
#             Alesha Dixon       0.84      0.87      0.85       135
#             Alex Salmond       0.92      0.95      0.94       116
#              Alexa Chung       0.93      0.85      0.89       130
#  Alfredo Pérez Rubalcaba       0.90      0.95      0.93       105
#           Aléxis Tsípras       0.92      0.91      0.91       149
#              Amber Heard       0.70      0.82      0.76       143
#                Amy Adams       0.79      0.80      0.79       127
#          Andie MacDowell       0.84      0.93      0.88       125
#              Boris Tadić       0.93      0.93      0.93       125
#     Bronisław Komorowski       0.93      0.96      0.94       149
#
#                 accuracy                           0.87      2025
#                macro avg       0.88      0.87      0.87      2025
#             weighted avg       0.88      0.87      0.87      2025

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle

# 1. Get True Labels and Predicted Probabilities
print("Getting predictions for ROC curve...")
y_true_indices = []
y_probs = []

# Iterate through Test Dataset
for images, labels in test_ds:
    preds = model.predict(images, verbose=0)
    y_probs.extend(preds)
    y_true_indices.extend(labels.numpy())

y_true_indices = np.array(y_true_indices)
y_probs = np.array(y_probs)

# 2. Binarize the labels (One-hot encoding for ROC)
lb = LabelBinarizer()
lb.fit(range(len(class_names)))
y_true_bin = lb.transform(y_true_indices)

# 3. Compute ROC curve and ROC area for each class
n_classes = len(class_names)
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Compute Micro-Average ROC (Overall performance)
fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# 5. Plotting
plt.figure(figsize=(10, 8))

# Plot Micro-Average (The "Summary" Line)
plt.plot(fpr["micro"], tpr["micro"],
         label=f'micro-average ROC (area = {roc_auc["micro"]:.2f})',
         color='deeppink', linestyle=':', linewidth=4)

# Plot each individual class curve
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of {class_names[i]} (area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2) # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Getting predictions for ROC curve...
